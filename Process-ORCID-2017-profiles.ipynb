# %% [markdown]
# # Reading and analysing the ORCID public profiles
# This notebook describes the process of extracting and analyising data from the 2017 public data release. The analysis uses the activities extract of the profiles in JSON format (https://doi.org/10.6084/m9.figshare.5479792.v1).
#
# The method is based on the one used by Bohannon (2017, https://doi.org.10.1126/science.aal1189) for which dataset and scripts can be found here: http://dx.doi.org/10.5061/dryad.48s16.
#
# Here, the complete ORCID profiles are used to add information about researcher urls to the dataset for analysis of current affiliations.

# %%
# python tarfile module is too memory expensive for reading the uncompressed archive. 
# Use command line to extract the archive onto an external hard drive

#tar -xzvf public_profiles_API2.0_2017_10_json.tar.gz -C ~/destination

# %%
import json, os, sys
import pandas as pd

# %% [markdown]
# ## Setup
# Load a couple of profiles to adapt the functions to the new ORCID message schema and the use of whole profiles:

# %%
#load my own ORCID profile to check contents
json.load(open("/media/eva/Eva-passport/ORCIDpubData2017/public_profiles_API-2.0_2017_10_json/9/0000-0003-4965-2969.json"))
# Out:
# {'activities-summary': {'educations': {'education-summary': [{'created-date': {'value': 1499540565501},
#      'department-name': 'Computer Science',
#      'end-date': None,
#      'last-modified-date': {'value': 1499540565501},
#      'organization': {'address': {'city': 'St Andrews',
#        'country': 'GB',
#        'region': None},
#       'disambiguated-organization': None,
#       'name': 'University of St Andrews'},
#      'path': '/0000-0003-4965-2969/education/4229471',
#      'put-code': 4229471,
#      'role-title': 'Management and Information Technology',
#      'source': {'source-client-id': None,
#       'source-name': {'value': 'Eva Borger'},
#       'source-orcid': {'host': 'orcid.org',
#        'path': '0000-0003-4965-2969',
#        'uri': 'http://orcid.org/0000-0003-4965-2969'}},
#      'start-date': {'day': {'value': '12'},
#       'month': {'value': '09'},
#       'year': {'value': '2016'}},
#      'visibility': 'public'},
#     {'created-date': {'value': 1499540208691},
#      'department-name': 'Medicine',
#      'end-date': {'day': {'value': '28'},
#       'month': {'value': '11'},
#       'year': {'value': '2007'}},
#      'last-modified-date': {'value': 1499540208691},
#      'organization': {'address': {'city': 'Marburg',
#        'country': 'DE',
#        'region': 'Hessen'},
#       'disambiguated-organization': {'disambiguated-organization-identifier': '9377',
#        'disambiguation-source': 'RINGGOLD'},
#       'name': 'Philipps-Universität Marburg'},
#      'path': '/0000-0003-4965-2969/education/4229458',
#      'put-code': 4229458,
#      'role-title': 'Diplom Humanbiologin',
#      'source': {'source-client-id': None,
#       'source-name': {'value': 'Eva Borger'},
#       'source-orcid': {'host': 'orcid.org',
#        'path': '0000-0003-4965-2969',
#        'uri': 'http://orcid.org/0000-0003-4965-2969'}},
#      'start-date': {'day': {'value': '10'},
#       'month': {'value': '10'},
#       'year': {'value': '2002'}},
#      'visibility': 'public'},
#     {'created-date': {'value': 1490289964728},
#      'department-name': 'Biology',
#      'end-date': {'day': {'value': '06'},
#       'month': {'value': '06'},
#       'year': {'value': '2012'}},
#      'last-modified-date': {'value': 1490289964728},
#      'organization': {'address': {'city': 'St Andrews',
#        'country': 'GB',
#        'region': 'Fife'},
#       'disambiguated-organization': None,
#       'name': 'University of St Andrews'},
#      'path': '/0000-0003-4965-2969/education/3489281',
#      'put-code': 3489281,
#      'role-title': 'PhD',
#      'source': {'source-client-id': None,
#       'source-name': {'value': 'Eva Borger'},
#       'source-orcid': {'host': 'orcid.org',
#        'path': '0000-0003-4965-2969',
#        'uri': 'http://orcid.org/0000-0003-4965-2969'}},
#      'start-date': {'day': {'value': '01'},
#       'month': {'value': '10'},
#       'year': {'value': '2008'}},
#      'visibility': 'public'}],
#    'last-modified-date': {'value': 1499540565501},
#    'path': '/0000-0003-4965-2969/educations'},
#   'employments': {'employment-summary': [{'created-date': {'value': 1506537510098},
#      'department-name': 'School of Biology',
#      'end-date': {'day': {'value': '31'},
#       'month': {'value': '07'},
#       'year': {'value': '2014'}},
#      'last-modified-date': {'value': 1506537510098},
#      'organization': {'address': {'city': 'St Andrews',
#        'country': 'GB',
#        'region': None},
#       'disambiguated-organization': None,
#       'name': 'University of St Andrews'},
#      'path': '/0000-0003-4965-2969/employment/4689914',
#      'put-code': 4689914,
#      'role-title': 'Postdoctoral Researcher',
#      'source': {'source-client-id': None,
#       'source-name': {'value': 'Eva Borger'},
#       'source-orcid': {'host': 'orcid.org',
#        'path': '0000-0003-4965-2969',
#        'uri': 'http://orcid.org/0000-0003-4965-2969'}},
#      'start-date': {'day': {'value': '01'},
#       'month': {'value': '06'},
#       'year': {'value': '2012'}},
#      'visibility': 'public'},
#     {'created-date': {'value': 1506537338697},
#      'department-name': None,
#      'end-date': None,
#      'last-modified-date': {'value': 1506537338697},
#      'organization': {'address': {'city': 'St Andrews',
#        'country': 'GB',
#        'region': None},
#       'disambiguated-organization': None,
#       'name': 'The University of St Andrews'},
#      'path': '/0000-0003-4965-2969/employment/4689897',
#      'put-code': 4689897,
#      'role-title': None,
#      'source': {'source-client-id': {'host': 'orcid.org',
#        'path': 'APP-Q1JBREKLK73FSBP5',
#        'uri': 'http://orcid.org/client/APP-Q1JBREKLK73FSBP5'},
#       'source-name': {'value': 'University of St Andrews CRIS'},
#       'source-orcid': None},
#      'start-date': None,
#      'visibility': 'public'},
#     {'created-date': {'value': 1499540339041},
#      'department-name': 'Medicine (Anatomy and Cell Biology)',
#      'end-date': {'day': None,
#       'month': {'value': '07'},
#       'year': {'value': '2008'}},
#      'last-modified-date': {'value': 1499541721133},
#      'organization': {'address': {'city': 'Marburg',
#        'country': 'DE',
#        'region': 'Hessen'},
#       'disambiguated-organization': {'disambiguated-organization-identifier': '9377',
#        'disambiguation-source': 'RINGGOLD'},
#       'name': 'Philipps-Universität Marburg'},
#      'path': '/0000-0003-4965-2969/employment/4229467',
#      'put-code': 4229467,
#      'role-title': 'Teaching Fellow',
#      'source': {'source-client-id': None,
#       'source-name': {'value': 'Eva Borger'},
#       'source-orcid': {'host': 'orcid.org',
#        'path': '0000-0003-4965-2969',
#        'uri': 'http://orcid.org/0000-0003-4965-2969'}},
#      'start-date': {'day': None,
#       'month': {'value': '02'},
#       'year': {'value': '2008'}},
#      'visibility': 'public'},
#     {'created-date': {'value': 1488369476532},
#      'department-name': 'Centre for Regenerative Medicine',
#      'end-date': {'day': {'value': '31'},
#       'month': {'value': '07'},
#       'year': {'value': '2016'}},
#      'last-modified-date': {'value': 1492715303244},
#      'organization': {'address': {'city': 'Edinburgh',
#        'country': 'GB',
#        'region': 'Edinburgh'},
#       'disambiguated-organization': {'disambiguated-organization-identifier': '3124',
#        'disambiguation-source': 'RINGGOLD'},
#       'name': 'University of Edinburgh'},
#      'path': '/0000-0003-4965-2969/employment/3318104',
#      'put-code': 3318104,
#      'role-title': 'UKRMP Postdoctoral Researcher',
#      'source': {'source-client-id': None,
#       'source-name': {'value': 'Eva Borger'},
#       'source-orcid': {'host': 'orcid.org',
#        'path': '0000-0003-4965-2969',
#        'uri': 'http://orcid.org/0000-0003-4965-2969'}},
#      'start-date': {'day': {'value': '01'},
#       'month': {'value': '08'},
#       'year': {'value': '2014'}},
#      'visibility': 'public'}],
#    'last-modified-date': {'value': 1506537510098},
#    'path': '/0000-0003-4965-2969/employments'},
#   'fundings': {'group': None,
#    'last-modified-date': None,
#    'path': '/0000-0003-4965-2969/fundings'},
#   'last-modified-date': {'value': 1506855714013},
#   'path': '/0000-0003-4965-2969/activities',
#   'peer-reviews': {'group': None,
#    'last-modified-date': None,
#    'path': '/0000-0003-4965-2969/peer-reviews'},
#   'works': {'group': [{'external-ids': {'external-id': [{'external-id-relationship': 'self',
#         'external-id-type': 'source-work-id',
#         'external-id-url': None,
#         'external-id-value': '8de63e50-992a-4868-8fed-462a7e1b0206'},
#        {'external-id-relationship': 'self',
#         'external-id-type': 'eid',
#         'external-id-url': None,
#         'external-id-value': '2-s2.0-84952886825'},
#        {'external-id-relationship': 'self',
#         'external-id-type': 'doi',
#         'external-id-url': None,
#         'external-id-value': '10.1016/j.phrs.2015.12.008'}]},
#      'last-modified-date': {'value': 1506855714013},
#      'work-summary': [{'created-date': {'value': 1488369331673},
#        'display-index': '0',
#        'external-ids': {'external-id': [{'external-id-relationship': 'self',
#           'external-id-type': 'source-work-id',
#           'external-id-url': None,
#           'external-id-value': '8de63e50-992a-4868-8fed-462a7e1b0206'},
#          {'external-id-relationship': 'self',
#           'external-id-type': 'eid',
#           'external-id-url': None,
#           'external-id-value': '2-s2.0-84952886825'},
#          {'external-id-relationship': 'self',
#           'external-id-type': 'doi',
#           'external-id-url': None,
#           'external-id-value': '10.1016/j.phrs.2015.12.008'}]},
#        'last-modified-date': {'value': 1506855714013},
#        'path': '/0000-0003-4965-2969/work/30766999',
#        'publication-date': {'day': None,
#         'media-type': None,
#         'month': {'value': '02'},
#         'year': {'value': '2016'}},
#        'put-code': 30766999,
#        'source': {'source-client-id': {'host': 'orcid.org',
#          'path': 'APP-Q1JBREKLK73FSBP5',
#          'uri': 'http://orcid.org/client/APP-Q1JBREKLK73FSBP5'},
#         'source-name': {'value': 'University of St Andrews CRIS'},
#         'source-orcid': None},
#        'title': {'subtitle': None,
#         'title': {'value': 'Activation of a synapse weakening pathway by human Val66 but not Met66 pro-brain-derived neurotrophic factor (proBDNF)'},
#         'translated-title': None},
#        'type': 'journal-article',
#        'visibility': 'public'},
#       {'created-date': {'value': 1493719716915},
#        'display-index': '0',
#        'external-ids': {'external-id': [{'external-id-relationship': 'self',
#           'external-id-type': 'doi',
#           'external-id-url': None,
#           'external-id-value': '10.1016/j.phrs.2015.12.008'},
#          {'external-id-relationship': 'self',
#           'external-id-type': 'eid',
#           'external-id-url': None,
#           'external-id-value': '2-s2.0-84952886825'}]},
#        'last-modified-date': {'value': 1504436491054},
#        'path': '/0000-0003-4965-2969/work/32325373',
#        'publication-date': {'day': None,
#         'media-type': None,
#         'month': None,
#         'year': {'value': '2016'}},
#        'put-code': 32325373,
#        'source': {'source-client-id': {'host': 'orcid.org',
#          'path': '0000-0002-5982-8983',
#          'uri': 'http://orcid.org/client/0000-0002-5982-8983'},
#         'source-name': {'value': 'Scopus to ORCID'},
#         'source-orcid': None},
#        'title': {'subtitle': None,
#         'title': {'value': 'Activation of a synapse weakening pathway by human Val66 but not Met66 pro-brain-derived neurotrophic factor (proBDNF)'},
#         'translated-title': None},
#        'type': 'journal-article',
#        'visibility': 'public'}]},
#     {'external-ids': {'external-id': [{'external-id-relationship': 'self',
#         'external-id-type': 'doi',
#         'external-id-url': None,
#         'external-id-value': '10.1002/glia.22870'}]},
#      'last-modified-date': {'value': 1504436491054},
#      'work-summary': [{'created-date': {'value': 1499369821502},
#        'display-index': '6',
#        'external-ids': {'external-id': [{'external-id-relationship': 'self',
#           'external-id-type': 'doi',
#           'external-id-url': None,
#           'external-id-value': '10.1002/glia.22870'}]},
#        'last-modified-date': {'value': 1504436491054},
#        'path': '/0000-0003-4965-2969/work/34734008',
#        'publication-date': {'day': None,
#         'media-type': None,
#         'month': {'value': '06'},
#         'year': {'value': '2015'}},
#        'put-code': 34734008,
#        'source': {'source-client-id': None,
#         'source-name': {'value': 'Eva Borger'},
#         'source-orcid': {'host': 'orcid.org',
#          'path': '0000-0003-4965-2969',
#          'uri': 'http://orcid.org/0000-0003-4965-2969'}},
#        'title': {'subtitle': None,
#         'title': {'value': 'The microenvironment of oligodendrocyte precursor cells in CNS regeneration'},
#         'translated-title': None},
#        'type': 'conference-poster',
#        'visibility': 'public'},
#       {'created-date': {'value': 1499331525739},
#        'display-index': '5',
#        'external-ids': {'external-id': [{'external-id-relationship': 'self',
#           'external-id-type': 'doi',
#           'external-id-url': None,
#           'external-id-value': '10.1002/glia.22870'}]},
#        'last-modified-date': {'value': 1504436491054},
#        'path': '/0000-0003-4965-2969/work/34733421',
#        'publication-date': {'day': None,
#         'media-type': None,
#         'month': {'value': '06'},
#         'year': {'value': '2015'}},
#        'put-code': 34733421,
#        'source': {'source-client-id': {'host': 'orcid.org',
#          'path': '0000-0002-3054-1567',
#          'uri': 'http://orcid.org/client/0000-0002-3054-1567'},
#         'source-name': {'value': 'CrossRef Metadata Search'},
#         'source-orcid': None},
#        'title': {'subtitle': None,
#         'title': {'value': 'GLIA Bilbao 2015: Abstracts Oral Presentations, Posters, Indexes'},
#         'translated-title': None},
#        'type': 'journal-article',
#        'visibility': 'public'}]},
#     {'external-ids': {'external-id': [{'external-id-relationship': 'self',
#         'external-id-type': 'eid',
#         'external-id-url': None,
#         'external-id-value': '2-s2.0-84912034785'},
#        {'external-id-relationship': 'self',
#         'external-id-type': 'doi',
#         'external-id-url': None,
#         'external-id-value': '10.1097/NEN.0000000000000138'},
#        {'external-id-relationship': 'self',
#         'external-id-type': 'eid',
#         'external-id-url': None,
#         'external-id-value': '2-s2.0-84915767481'},
#        {'external-id-relationship': 'self',
#         'external-id-type': 'pmid',
#         'external-id-url': None,
#         'external-id-value': '25383639'},
#        {'external-id-relationship': 'self',
#         'external-id-type': 'source-work-id',
#         'external-id-url': None,
#         'external-id-value': '37f0eb29-efa1-4793-8d52-cd24943b6896'}]},
#      'last-modified-date': {'value': 1506855714013},
#      'work-summary': [{'created-date': {'value': 1488369331674},
#        'display-index': '4',
#        'external-ids': {'external-id': [{'external-id-relationship': 'self',
#           'external-id-type': 'source-work-id',
#           'external-id-url': None,
#           'external-id-value': '37f0eb29-efa1-4793-8d52-cd24943b6896'},
#          {'external-id-relationship': 'self',
#           'external-id-type': 'eid',
#           'external-id-url': None,
#           'external-id-value': '2-s2.0-84915767481'},
#          {'external-id-relationship': 'self',
#           'external-id-type': 'eid',
#           'external-id-url': None,
#           'external-id-value': '2-s2.0-84912034785'},
#          {'external-id-relationship': 'self',
#           'external-id-type': 'eid',
#           'external-id-url': None,
#           'external-id-value': '2-s2.0-84915767481'},
#          {'external-id-relationship': 'self',
#           'external-id-type': 'pmid',
#           'external-id-url': None,
#           'external-id-value': '25383639'},
#          {'external-id-relationship': 'self',
#           'external-id-type': 'doi',
#           'external-id-url': None,
#           'external-id-value': '10.1097/NEN.0000000000000138'}]},
#        'last-modified-date': {'value': 1506855714013},
#        'path': '/0000-0003-4965-2969/work/30767000',
#        'publication-date': {'day': None,
#         'media-type': None,
#         'month': {'value': '10'},
#         'year': {'value': '2014'}},
#        'put-code': 30767000,
#        'source': {'source-client-id': {'host': 'orcid.org',
#          'path': 'APP-Q1JBREKLK73FSBP5',
#          'uri': 'http://orcid.org/client/APP-Q1JBREKLK73FSBP5'},
#         'source-name': {'value': 'University of St Andrews CRIS'},
#         'source-orcid': None},
#        'title': {'subtitle': None,
#         'title': {'value': 'The calcium-binding protein EFhd2 modulates synapse formation in vitro and Is linked to human dementia'},
#         'translated-title': None},
#        'type': 'journal-article',
#        'visibility': 'public'}]},
#     {'external-ids': {'external-id': [{'external-id-relationship': 'self',
#         'external-id-type': 'eid',
#         'external-id-url': None,
#         'external-id-value': '2-s2.0-84915821571'},
#        {'external-id-relationship': 'self',
#         'external-id-type': 'doi',
#         'external-id-url': None,
#         'external-id-value': '10.1371/journal.pone.0103976'},
#        {'external-id-relationship': 'self',
#         'external-id-type': 'source-work-id',
#         'external-id-url': None,
#         'external-id-value': '6beee6b4-e76d-46b9-aa49-68dfbf150a72'}]},
#      'last-modified-date': {'value': 1506855714013},
#      'work-summary': [{'created-date': {'value': 1488369331674},
#        'display-index': '0',
#        'external-ids': {'external-id': [{'external-id-relationship': 'self',
#           'external-id-type': 'source-work-id',
#           'external-id-url': None,
#           'external-id-value': '6beee6b4-e76d-46b9-aa49-68dfbf150a72'},
#          {'external-id-relationship': 'self',
#           'external-id-type': 'eid',
#           'external-id-url': None,
#           'external-id-value': '2-s2.0-84915821571'},
#          {'external-id-relationship': 'self',
#           'external-id-type': 'doi',
#           'external-id-url': None,
#           'external-id-value': '10.1371/journal.pone.0103976'}]},
#        'last-modified-date': {'value': 1506855714013},
#        'path': '/0000-0003-4965-2969/work/30767001',
#        'publication-date': {'day': {'value': '18'},
#         'media-type': None,
#         'month': {'value': '08'},
#         'year': {'value': '2014'}},
#        'put-code': 30767001,
#        'source': {'source-client-id': {'host': 'orcid.org',
#          'path': 'APP-Q1JBREKLK73FSBP5',
#          'uri': 'http://orcid.org/client/APP-Q1JBREKLK73FSBP5'},
#         'source-name': {'value': 'University of St Andrews CRIS'},
#         'source-orcid': None},
#        'title': {'subtitle': None,
#         'title': {'value': 'The Ca2+ sensor protein Swiprosin-1/EFhd2 is present in neurites and involved in kinesin-mediated transport in neurons'},
#         'translated-title': None},
#        'type': 'journal-article',
#        'visibility': 'public'},
#       {'created-date': {'value': 1493719716913},
#        'display-index': '0',
#        'external-ids': {'external-id': [{'external-id-relationship': 'self',
#           'external-id-type': 'doi',
#           'external-id-url': None,
#           'external-id-value': '10.1371/journal.pone.0103976'},
#          {'external-id-relationship': 'self',
#           'external-id-type': 'eid',
#           'external-id-url': None,
#           'external-id-value': '2-s2.0-84915821571'}]},
#        'last-modified-date': {'value': 1504436491054},
#        'path': '/0000-0003-4965-2969/work/32325371',
#        'publication-date': {'day': None,
#         'media-type': None,
#         'month': None,
#         'year': {'value': '2014'}},
#        'put-code': 32325371,
#        'source': {'source-client-id': {'host': 'orcid.org',
#          'path': '0000-0002-5982-8983',
#          'uri': 'http://orcid.org/client/0000-0002-5982-8983'},
#         'source-name': {'value': 'Scopus to ORCID'},
#         'source-orcid': None},
#        'title': {'subtitle': None,
#         'title': {'value': 'The Ca&lt;sup&gt;2+&lt;/sup&gt; sensor protein swiprosin-1/EFhd2 is present in neurites and involved in kinesin-mediated transport in neurons'},
#         'translated-title': None},
#        'type': 'journal-article',
#        'visibility': 'public'}]},
#     {'external-ids': {'external-id': [{'external-id-relationship': 'self',
#         'external-id-type': 'doi',
#         'external-id-url': None,
#         'external-id-value': '10.1016/j.ejca.2013.12.019'},
#        {'external-id-relationship': 'self',
#         'external-id-type': 'source-work-id',
#         'external-id-url': None,
#         'external-id-value': 'aa7f6b8c-d6ae-45d3-aace-021d449c461c'},
#        {'external-id-relationship': 'self',
#         'external-id-type': 'pmid',
#         'external-id-url': None,
#         'external-id-value': '24462375'},
#        {'external-id-relationship': 'self',
#         'external-id-type': 'eid',
#         'external-id-url': None,
#         'external-id-value': '2-s2.0-84896700681'}]},
#      'last-modified-date': {'value': 1506855714013},
#      'work-summary': [{'created-date': {'value': 1488369331674},
#        'display-index': '0',
#        'external-ids': {'external-id': [{'external-id-relationship': 'self',
#           'external-id-type': 'source-work-id',
#           'external-id-url': None,
#           'external-id-value': 'aa7f6b8c-d6ae-45d3-aace-021d449c461c'},
#          {'external-id-relationship': 'self',
#           'external-id-type': 'pmid',
#           'external-id-url': None,
#           'external-id-value': '24462375'},
#          {'external-id-relationship': 'self',
#           'external-id-type': 'eid',
#           'external-id-url': None,
#           'external-id-value': '2-s2.0-84896700681'},
#          {'external-id-relationship': 'self',
#           'external-id-type': 'doi',
#           'external-id-url': None,
#           'external-id-value': '10.1016/j.ejca.2013.12.019'}]},
#        'last-modified-date': {'value': 1506855714013},
#        'path': '/0000-0003-4965-2969/work/30767002',
#        'publication-date': {'day': None,
#         'media-type': None,
#         'month': {'value': '03'},
#         'year': {'value': '2014'}},
#        'put-code': 30767002,
#        'source': {'source-client-id': {'host': 'orcid.org',
#          'path': 'APP-Q1JBREKLK73FSBP5',
#          'uri': 'http://orcid.org/client/APP-Q1JBREKLK73FSBP5'},
#         'source-name': {'value': 'University of St Andrews CRIS'},
#         'source-orcid': None},
#        'title': {'subtitle': None,
#         'title': {'value': 'Regulation of exosome release from mammary epithelial and breast cancer cells - a new regulatory pathway'},
#         'translated-title': None},
#        'type': 'journal-article',
#        'visibility': 'public'},
#       {'created-date': {'value': 1493719716914},
#        'display-index': '0',
#        'external-ids': {'external-id': [{'external-id-relationship': 'self',
#           'external-id-type': 'doi',
#           'external-id-url': None,
#           'external-id-value': '10.1016/j.ejca.2013.12.019'},
#          {'external-id-relationship': 'self',
#           'external-id-type': 'eid',
#           'external-id-url': None,
#           'external-id-value': '2-s2.0-84896700681'}]},
#        'last-modified-date': {'value': 1504436491054},
#        'path': '/0000-0003-4965-2969/work/32325372',
#        'publication-date': {'day': None,
#         'media-type': None,
#         'month': None,
#         'year': {'value': '2014'}},
#        'put-code': 32325372,
#        'source': {'source-client-id': {'host': 'orcid.org',
#          'path': '0000-0002-5982-8983',
#          'uri': 'http://orcid.org/client/0000-0002-5982-8983'},
#         'source-name': {'value': 'Scopus to ORCID'},
#         'source-orcid': None},
#        'title': {'subtitle': None,
#         'title': {'value': 'Regulation of exosome release from mammary epithelial and breast cancer cells-A new regulatory pathway'},
#         'translated-title': None},
#        'type': 'journal-article',
#        'visibility': 'public'}]},
#     {'external-ids': {'external-id': [{'external-id-relationship': 'self',
#         'external-id-type': 'eid',
#         'external-id-url': None,
#         'external-id-value': '2-s2.0-84898056868'},
#        {'external-id-relationship': 'self',
#         'external-id-type': 'doi',
#         'external-id-url': None,
#         'external-id-value': '10.1016/j.actbio.2013.12.057'},
#        {'external-id-relationship': 'self',
#         'external-id-type': 'source-work-id',
#         'external-id-url': None,
#         'external-id-value': '1a9ebacb-7d84-4a45-9af9-305dc02373b3'},
#        {'external-id-relationship': 'self',
#         'external-id-type': 'pmid',
#         'external-id-url': None,
#         'external-id-value': '24406196'}]},
#      'last-modified-date': {'value': 1506855714013},
#      'work-summary': [{'created-date': {'value': 1488369331674},
#        'display-index': '0',
#        'external-ids': {'external-id': [{'external-id-relationship': 'self',
#           'external-id-type': 'source-work-id',
#           'external-id-url': None,
#           'external-id-value': '1a9ebacb-7d84-4a45-9af9-305dc02373b3'},
#          {'external-id-relationship': 'self',
#           'external-id-type': 'eid',
#           'external-id-url': None,
#           'external-id-value': '2-s2.0-84898056868'},
#          {'external-id-relationship': 'self',
#           'external-id-type': 'pmid',
#           'external-id-url': None,
#           'external-id-value': '24406196'},
#          {'external-id-relationship': 'self',
#           'external-id-type': 'doi',
#           'external-id-url': None,
#           'external-id-value': '10.1016/j.actbio.2013.12.057'}]},
#        'last-modified-date': {'value': 1506855714013},
#        'path': '/0000-0003-4965-2969/work/30767003',
#        'publication-date': {'day': None,
#         'media-type': None,
#         'month': None,
#         'year': {'value': '2014'}},
#        'put-code': 30767003,
#        'source': {'source-client-id': {'host': 'orcid.org',
#          'path': 'APP-Q1JBREKLK73FSBP5',
#          'uri': 'http://orcid.org/client/APP-Q1JBREKLK73FSBP5'},
#         'source-name': {'value': 'University of St Andrews CRIS'},
#         'source-orcid': None},
#        'title': {'subtitle': None,
#         'title': {'value': 'Discrimination of bladder cancer cells from normal urothelial cells with high specificity and sensitivity'},
#         'translated-title': None},
#        'type': 'journal-article',
#        'visibility': 'public'},
#       {'created-date': {'value': 1493719716912},
#        'display-index': '0',
#        'external-ids': {'external-id': [{'external-id-relationship': 'self',
#           'external-id-type': 'doi',
#           'external-id-url': None,
#           'external-id-value': '10.1016/j.actbio.2013.12.057'},
#          {'external-id-relationship': 'self',
#           'external-id-type': 'eid',
#           'external-id-url': None,
#           'external-id-value': '2-s2.0-84898056868'}]},
#        'last-modified-date': {'value': 1504436491054},
#        'path': '/0000-0003-4965-2969/work/32325370',
#        'publication-date': {'day': None,
#         'media-type': None,
#         'month': None,
#         'year': {'value': '2014'}},
#        'put-code': 32325370,
#        'source': {'source-client-id': {'host': 'orcid.org',
#          'path': '0000-0002-5982-8983',
#          'uri': 'http://orcid.org/client/0000-0002-5982-8983'},
#         'source-name': {'value': 'Scopus to ORCID'},
#         'source-orcid': None},
#        'title': {'subtitle': None,
#         'title': {'value': 'Discrimination of bladder cancer cells from normal urothelial cells with high specificity and sensitivity: Combined application of atomic force microscopy and modulated Raman spectroscopy'},
#         'translated-title': None},
#        'type': 'journal-article',
#        'visibility': 'public'}]},
#     {'external-ids': {'external-id': [{'external-id-relationship': 'self',
#         'external-id-type': 'doi',
#         'external-id-url': None,
#         'external-id-value': '10.1016/j.jalz.2013.05.670'}]},
#      'last-modified-date': {'value': 1504436491054},
#      'work-summary': [{'created-date': {'value': 1490375110978},
#        'display-index': '0',
#        'external-ids': {'external-id': [{'external-id-relationship': 'self',
#           'external-id-type': 'doi',
#           'external-id-url': None,
#           'external-id-value': '10.1016/j.jalz.2013.05.670'}]},
#        'last-modified-date': {'value': 1504436491054},
#        'path': '/0000-0003-4965-2969/work/31328856',
#        'publication-date': {'day': None,
#         'media-type': None,
#         'month': {'value': '07'},
#         'year': {'value': '2013'}},
#        'put-code': 31328856,
#        'source': {'source-client-id': {'host': 'orcid.org',
#          'path': '0000-0002-3054-1567',
#          'uri': 'http://orcid.org/client/0000-0002-3054-1567'},
#         'source-name': {'value': 'CrossRef Metadata Search'},
#         'source-orcid': None},
#        'title': {'subtitle': None,
#         'title': {'value': 'The novel calcium-binding protein EFHD2 is linked to frontotemporal dementia'},
#         'translated-title': None},
#        'type': 'journal-article',
#        'visibility': 'public'}]},
#     {'external-ids': {'external-id': [{'external-id-relationship': 'self',
#         'external-id-type': 'doi',
#         'external-id-url': None,
#         'external-id-value': '10.2174/1567205011310010004'},
#        {'external-id-relationship': 'self',
#         'external-id-type': 'pmc',
#         'external-id-url': None,
#         'external-id-value': ' 3674883'},
#        {'external-id-relationship': 'self',
#         'external-id-type': 'pmid',
#         'external-id-url': None,
#         'external-id-value': '22742981'},
#        {'external-id-relationship': 'self',
#         'external-id-type': 'pmc',
#         'external-id-url': None,
#         'external-id-value': '3674883'},
#        {'external-id-relationship': 'self',
#         'external-id-type': 'source-work-id',
#         'external-id-url': None,
#         'external-id-value': 'a40ecad0-ada3-470c-a087-506cba063b30'}]},
#      'last-modified-date': {'value': 1506855714013},
#      'work-summary': [{'created-date': {'value': 1488369331675},
#        'display-index': '3',
#        'external-ids': {'external-id': [{'external-id-relationship': 'self',
#           'external-id-type': 'source-work-id',
#           'external-id-url': None,
#           'external-id-value': 'a40ecad0-ada3-470c-a087-506cba063b30'},
#          {'external-id-relationship': 'self',
#           'external-id-type': 'doi',
#           'external-id-url': None,
#           'external-id-value': '10.2174/1567205011310010004'}]},
#        'last-modified-date': {'value': 1506855714013},
#        'path': '/0000-0003-4965-2969/work/30767004',
#        'publication-date': {'day': None,
#         'media-type': None,
#         'month': {'value': '12'},
#         'year': {'value': '2012'}},
#        'put-code': 30767004,
#        'source': {'source-client-id': {'host': 'orcid.org',
#          'path': 'APP-Q1JBREKLK73FSBP5',
#          'uri': 'http://orcid.org/client/APP-Q1JBREKLK73FSBP5'},
#         'source-name': {'value': 'University of St Andrews CRIS'},
#         'source-orcid': None},
#        'title': {'subtitle': None,
#         'title': {'value': "Is Amyloid binding alcohol dehydrogenase a drug target for treating Alzheimer's disease?"},
#         'translated-title': None},
#        'type': 'journal-article',
#        'visibility': 'public'},
#       {'created-date': {'value': 1488377836365},
#        'display-index': '1',
#        'external-ids': {'external-id': [{'external-id-relationship': 'self',
#           'external-id-type': 'source-work-id',
#           'external-id-url': None,
#           'external-id-value': 'a40ecad0-ada3-470c-a087-506cba063b30'},
#          {'external-id-relationship': 'self',
#           'external-id-type': 'doi',
#           'external-id-url': None,
#           'external-id-value': '10.2174/1567205011310010004'},
#          {'external-id-relationship': 'self',
#           'external-id-type': 'pmc',
#           'external-id-url': None,
#           'external-id-value': ' 3674883'},
#          {'external-id-relationship': 'self',
#           'external-id-type': 'pmid',
#           'external-id-url': None,
#           'external-id-value': '22742981'}]},
#        'last-modified-date': {'value': 1504436491054},
#        'path': '/0000-0003-4965-2969/work/36289927',
#        'publication-date': {'day': None,
#         'media-type': None,
#         'month': {'value': '12'},
#         'year': {'value': '2012'}},
#        'put-code': 36289927,
#        'source': {'source-client-id': None,
#         'source-name': {'value': 'Eva Borger'},
#         'source-orcid': {'host': 'orcid.org',
#          'path': '0000-0003-4965-2969',
#          'uri': 'http://orcid.org/0000-0003-4965-2969'}},
#        'title': {'subtitle': None,
#         'title': {'value': "Is Amyloid binding alcohol dehydrogenase a drug target for treating Alzheimer's disease?"},
#         'translated-title': None},
#        'type': 'journal-article',
#        'visibility': 'public'},
#       {'created-date': {'value': 1503827426387},
#        'display-index': '0',
#        'external-ids': {'external-id': [{'external-id-relationship': 'self',
#           'external-id-type': 'pmc',
#           'external-id-url': None,
#           'external-id-value': '3674883'},
#          {'external-id-relationship': 'self',
#           'external-id-type': 'pmid',
#           'external-id-url': None,
#           'external-id-value': '22742981'}]},
#        'last-modified-date': {'value': 1504436491054},
#        'path': '/0000-0003-4965-2969/work/36287756',
#        'publication-date': {'day': None,
#         'media-type': None,
#         'month': {'value': '12'},
#         'year': {'value': '2012'}},
#        'put-code': 36287756,
#        'source': {'source-client-id': {'host': 'orcid.org',
#          'path': '0000-0002-9884-496X',
#          'uri': 'http://orcid.org/client/0000-0002-9884-496X'},
#         'source-name': {'value': 'ScienceOpen, Inc.'},
#         'source-orcid': None},
#        'title': {'subtitle': None,
#         'title': {'value': "Is amyloid binding alcohol dehydrogenase a drug target for treating Alzheimer's disease?"},
#         'translated-title': None},
#        'type': 'journal-article',
#        'visibility': 'public'}]},
#     {'external-ids': {'external-id': [{'external-id-relationship': 'self',
#         'external-id-type': 'source-work-id',
#         'external-id-url': None,
#         'external-id-value': 'c85fa05f-b1a0-4624-9cef-b370dc8cc897'},
#        {'external-id-relationship': 'self',
#         'external-id-type': 'doi',
#         'external-id-url': None,
#         'external-id-value': '10.1042/BST0390868'},
#        {'external-id-relationship': 'self',
#         'external-id-type': 'eid',
#         'external-id-url': None,
#         'external-id-value': '2-s2.0-79960868236'}]},
#      'last-modified-date': {'value': 1506855714013},
#      'work-summary': [{'created-date': {'value': 1488369331675},
#        'display-index': '0',
#        'external-ids': {'external-id': [{'external-id-relationship': 'self',
#           'external-id-type': 'source-work-id',
#           'external-id-url': None,
#           'external-id-value': 'c85fa05f-b1a0-4624-9cef-b370dc8cc897'},
#          {'external-id-relationship': 'self',
#           'external-id-type': 'eid',
#           'external-id-url': None,
#           'external-id-value': '2-s2.0-79960868236'},
#          {'external-id-relationship': 'self',
#           'external-id-type': 'doi',
#           'external-id-url': None,
#           'external-id-value': '10.1042/BST0390868'}]},
#        'last-modified-date': {'value': 1506855714013},
#        'path': '/0000-0003-4965-2969/work/30767005',
#        'publication-date': {'day': None,
#         'media-type': None,
#         'month': {'value': '08'},
#         'year': {'value': '2011'}},
#        'put-code': 30767005,
#        'source': {'source-client-id': {'host': 'orcid.org',
#          'path': 'APP-Q1JBREKLK73FSBP5',
#          'uri': 'http://orcid.org/client/APP-Q1JBREKLK73FSBP5'},
#         'source-name': {'value': 'University of St Andrews CRIS'},
#         'source-orcid': None},
#        'title': {'subtitle': None,
#         'title': {'value': "Mitochondrial β-amyloid in Alzheimer's disease"},
#         'translated-title': None},
#        'type': 'journal-article',
#        'visibility': 'public'},
#       {'created-date': {'value': 1493719716916},
#        'display-index': '0',
#        'external-ids': {'external-id': [{'external-id-relationship': 'self',
#           'external-id-type': 'doi',
#           'external-id-url': None,
#           'external-id-value': '10.1042/BST0390868'},
#          {'external-id-relationship': 'self',
#           'external-id-type': 'eid',
#           'external-id-url': None,
#           'external-id-value': '2-s2.0-79960868236'}]},
#        'last-modified-date': {'value': 1504436491054},
#        'path': '/0000-0003-4965-2969/work/32325374',
#        'publication-date': {'day': None,
#         'media-type': None,
#         'month': None,
#         'year': {'value': '2011'}},
#        'put-code': 32325374,
#        'source': {'source-client-id': {'host': 'orcid.org',
#          'path': '0000-0002-5982-8983',
#          'uri': 'http://orcid.org/client/0000-0002-5982-8983'},
#         'source-name': {'value': 'Scopus to ORCID'},
#         'source-orcid': None},
#        'title': {'subtitle': None,
#         'title': {'value': "Mitochondrial β-amyloid in Alzheimer's disease"},
#         'translated-title': None},
#        'type': 'journal-article',
#        'visibility': 'public'}]},
#     {'external-ids': {'external-id': [{'external-id-relationship': 'self',
#         'external-id-type': 'doi',
#         'external-id-url': None,
#         'external-id-value': '10.1042/BJ20091941'},
#        {'external-id-relationship': 'self',
#         'external-id-type': 'eid',
#         'external-id-url': None,
#         'external-id-value': '2-s2.0-77951931900'},
#        {'external-id-relationship': 'self',
#         'external-id-type': 'source-work-id',
#         'external-id-url': None,
#         'external-id-value': '7ffc66a2-9b93-4e02-b7b9-95759c47ac42'}]},
#      'last-modified-date': {'value': 1506855714013},
#      'work-summary': [{'created-date': {'value': 1493719717138},
#        'display-index': '2',
#        'external-ids': {'external-id': [{'external-id-relationship': 'self',
#           'external-id-type': 'doi',
#           'external-id-url': None,
#           'external-id-value': '10.1042/BJ20091941'},
#          {'external-id-relationship': 'self',
#           'external-id-type': 'eid',
#           'external-id-url': None,
#           'external-id-value': '2-s2.0-77951931900'}]},
#        'last-modified-date': {'value': 1504436491054},
#        'path': '/0000-0003-4965-2969/work/32325377',
#        'publication-date': {'day': None,
#         'media-type': None,
#         'month': None,
#         'year': {'value': '2010'}},
#        'put-code': 32325377,
#        'source': {'source-client-id': {'host': 'orcid.org',
#          'path': '0000-0002-5982-8983',
#          'uri': 'http://orcid.org/client/0000-0002-5982-8983'},
#         'source-name': {'value': 'Scopus to ORCID'},
#         'source-orcid': None},
#        'title': {'subtitle': None,
#         'title': {'value': "The consequences of mitochondrial amyloid β-peptide in Alzheimer's disease"},
#         'translated-title': None},
#        'type': 'journal-article',
#        'visibility': 'public'},
#       {'created-date': {'value': 1502017358374},
#        'display-index': '0',
#        'external-ids': {'external-id': [{'external-id-relationship': 'self',
#           'external-id-type': 'source-work-id',
#           'external-id-url': None,
#           'external-id-value': '7ffc66a2-9b93-4e02-b7b9-95759c47ac42'},
#          {'external-id-relationship': 'self',
#           'external-id-type': 'eid',
#           'external-id-url': None,
#           'external-id-value': '2-s2.0-77951931900'},
#          {'external-id-relationship': 'self',
#           'external-id-type': 'doi',
#           'external-id-url': None,
#           'external-id-value': '10.1042/BJ20091941'}]},
#        'last-modified-date': {'value': 1506855714013},
#        'path': '/0000-0003-4965-2969/work/35798660',
#        'publication-date': {'day': None,
#         'media-type': None,
#         'month': None,
#         'year': {'value': '2010'}},
#        'put-code': 35798660,
#        'source': {'source-client-id': {'host': 'orcid.org',
#          'path': 'APP-Q1JBREKLK73FSBP5',
#          'uri': 'http://orcid.org/client/APP-Q1JBREKLK73FSBP5'},
#         'source-name': {'value': 'University of St Andrews CRIS'},
#         'source-orcid': None},
#        'title': {'subtitle': None,
#         'title': {'value': 'The consequences of mitochondrial amyloid beta peptide in Alzheimer’s disease'},
#         'translated-title': None},
#        'type': 'journal-article',
#        'visibility': 'public'}]}],
#    'last-modified-date': {'value': 1506855714013},
#    'path': '/0000-0003-4965-2969/works'}},
#  'history': {'claimed': True,
#   'completion-date': None,
#   'creation-method': 'Member-referred',
#   'deactivation-date': None,
#   'last-modified-date': {'value': 1506855714067},
#   'source': None,
#   'submission-date': {'value': 1488369327783},
#   'verified-email': True,
#   'verified-primary-email': True},
#  'orcid-identifier': {'host': 'orcid.org',
#   'path': '0000-0003-4965-2969',
#   'uri': 'http://orcid.org/0000-0003-4965-2969'},
#  'path': '/0000-0003-4965-2969',
#  'person': {'addresses': {'address': [{'country': {'value': 'GB'},
#      'created-date': {'value': 1489089578702},
#      'display-index': 1,
#      'last-modified-date': {'value': 1489089578702},
#      'path': '/0000-0003-4965-2969/address/649574',
#      'put-code': 649574,
#      'source': {'source-client-id': None,
#       'source-name': {'value': 'Eva Borger'},
#       'source-orcid': {'host': 'orcid.org',
#        'path': '0000-0003-4965-2969',
#        'uri': 'http://orcid.org/0000-0003-4965-2969'}},
#      'visibility': 'public'}],
#    'last-modified-date': {'value': 1489089578702},
#    'path': '/0000-0003-4965-2969/address'},
#   'biography': None,
#   'emails': {'email': None,
#    'last-modified-date': None,
#    'path': '/0000-0003-4965-2969/email'},
#   'external-identifiers': {'external-identifier': [{'created-date': {'value': 1497024709013},
#      'display-index': 0,
#      'external-id-relationship': 'self',
#      'external-id-type': 'Scopus author ID',
#      'external-id-url': {'value': 'http://www.scopus.com/authid/detail.url?authorId=36058308200'},
#      'external-id-value': '36058308200',
#      'last-modified-date': {'value': 1497024709013},
#      'path': '/0000-0003-4965-2969/external-identifiers/728653',
#      'put-code': 728653,
#      'source': {'source-client-id': {'host': 'orcid.org',
#        'path': 'APP-Q1JBREKLK73FSBP5',
#        'uri': 'http://orcid.org/client/APP-Q1JBREKLK73FSBP5'},
#       'source-name': {'value': 'University of St Andrews CRIS'},
#       'source-orcid': None},
#      'visibility': 'public'}],
#    'last-modified-date': {'value': 1497024709013},
#    'path': '/0000-0003-4965-2969/external-identifiers'},
#   'keywords': {'keyword': [{'content': 'Information Technology',
#      'created-date': {'value': 1489158305143},
#      'display-index': 5,
#      'last-modified-date': {'value': 1503939314715},
#      'path': '/0000-0003-4965-2969/keywords/653336',
#      'put-code': 653336,
#      'source': {'source-client-id': None,
#       'source-name': {'value': 'Eva Borger'},
#       'source-orcid': {'host': 'orcid.org',
#        'path': '0000-0003-4965-2969',
#        'uri': 'http://orcid.org/0000-0003-4965-2969'}},
#      'visibility': 'public'},
#     {'content': 'Management',
#      'created-date': {'value': 1489158305142},
#      'display-index': 4,
#      'last-modified-date': {'value': 1503939314715},
#      'path': '/0000-0003-4965-2969/keywords/653335',
#      'put-code': 653335,
#      'source': {'source-client-id': None,
#       'source-name': {'value': 'Eva Borger'},
#       'source-orcid': {'host': 'orcid.org',
#        'path': '0000-0003-4965-2969',
#        'uri': 'http://orcid.org/0000-0003-4965-2969'}},
#      'visibility': 'public'},
#     {'content': 'Neurocience',
#      'created-date': {'value': 1503939293295},
#      'display-index': 3,
#      'last-modified-date': {'value': 1503939314715},
#      'path': '/0000-0003-4965-2969/keywords/772507',
#      'put-code': 772507,
#      'source': {'source-client-id': None,
#       'source-name': {'value': 'Eva Borger'},
#       'source-orcid': {'host': 'orcid.org',
#        'path': '0000-0003-4965-2969',
#        'uri': 'http://orcid.org/0000-0003-4965-2969'}},
#      'visibility': 'public'},
#     {'content': 'Dementia',
#      'created-date': {'value': 1489158165275},
#      'display-index': 2,
#      'last-modified-date': {'value': 1503939314715},
#      'path': '/0000-0003-4965-2969/keywords/653326',
#      'put-code': 653326,
#      'source': {'source-client-id': None,
#       'source-name': {'value': 'Eva Borger'},
#       'source-orcid': {'host': 'orcid.org',
#        'path': '0000-0003-4965-2969',
#        'uri': 'http://orcid.org/0000-0003-4965-2969'}},
#      'visibility': 'public'},
#     {'content': 'Multiple Sclerosis',
#      'created-date': {'value': 1489158165276},
#      'display-index': 1,
#      'last-modified-date': {'value': 1503939314715},
#      'path': '/0000-0003-4965-2969/keywords/653328',
#      'put-code': 653328,
#      'source': {'source-client-id': None,
#       'source-name': {'value': 'Eva Borger'},
#       'source-orcid': {'host': 'orcid.org',
#        'path': '0000-0003-4965-2969',
#        'uri': 'http://orcid.org/0000-0003-4965-2969'}},
#      'visibility': 'public'}],
#    'last-modified-date': {'value': 1503939314715},
#    'path': '/0000-0003-4965-2969/keywords'},
#   'last-modified-date': {'value': 1503939314715},
#   'name': {'created-date': {'value': 1488369327783},
#    'credit-name': {'value': 'Eva Borger'},
#    'family-name': {'value': 'Borger'},
#    'given-names': {'value': 'Eva'},
#    'last-modified-date': {'value': 1488369332308},
#    'path': '0000-0003-4965-2969',
#    'source': None,
#    'visibility': 'public'},
#   'other-names': {'last-modified-date': None,
#    'other-name': None,
#    'path': '/0000-0003-4965-2969/other-names'},
#   'path': '/0000-0003-4965-2969/person',
#   'researcher-urls': {'last-modified-date': {'value': 1503937678861},
#    'path': '/0000-0003-4965-2969/researcher-urls',
#    'researcher-url': [{'created-date': {'value': 1497532001802},
#      'display-index': 3,
#      'last-modified-date': {'value': 1503937678861},
#      'path': '/0000-0003-4965-2969/researcher-urls/1154642',
#      'put-code': 1154642,
#      'source': {'source-client-id': {'host': 'orcid.org',
#        'path': 'APP-Q1JBREKLK73FSBP5',
#        'uri': 'http://orcid.org/client/APP-Q1JBREKLK73FSBP5'},
#       'source-name': {'value': 'University of St Andrews CRIS'},
#       'source-orcid': None},
#      'url': {'value': 'https://risweb.st-andrews.ac.uk:443/portal/en/persons/eva-borger(0a7bac76-d21b-4729-a262-935688b7af58).html'},
#      'url-name': 'The University of St Andrews profile page',
#      'visibility': 'public'},
#     {'created-date': {'value': 1499541586504},
#      'display-index': 2,
#      'last-modified-date': {'value': 1503937678861},
#      'path': '/0000-0003-4965-2969/researcher-urls/1176627',
#      'put-code': 1176627,
#      'source': {'source-client-id': None,
#       'source-name': {'value': 'Eva Borger'},
#       'source-orcid': {'host': 'orcid.org',
#        'path': '0000-0003-4965-2969',
#        'uri': 'http://orcid.org/0000-0003-4965-2969'}},
#      'url': {'value': 'https://www.linkedin.com/in/evaborger/'},
#      'url-name': 'LinkedIn profile',
#      'visibility': 'public'},
#     {'created-date': {'value': 1503937678860},
#      'display-index': 1,
#      'last-modified-date': {'value': 1503937678860},
#      'path': '/0000-0003-4965-2969/researcher-urls/1230260',
#      'put-code': 1230260,
#      'source': {'source-client-id': None,
#       'source-name': {'value': 'Eva Borger'},
#       'source-orcid': {'host': 'orcid.org',
#        'path': '0000-0003-4965-2969',
#        'uri': 'http://orcid.org/0000-0003-4965-2969'}},
#      'url': {'value': 'https://www.scienceopen.com/user/evaborger'},
#      'url-name': 'ScienceOpen',
#      'visibility': 'public'}]}},
#  'preferences': {'locale': 'en'}}

# %%
#load an empty ORCID profile to check contents
json.load(open("/media/eva/Eva-passport/ORCIDpubData2017/public_profiles_API-2.0_2017_10_json/x/0000-0003-2914-115X.json"))

# %% [markdown]
# ## The functions needed to load the profiles

# %%
#the original file generator enumerated each file. Needed a workaround as we are iterating through subfolders. 
#running just the for-loop results in the same strucutre.
def file_generator(json_dir):
    ''' Using a generator allows pausing and restarting
    without having to figure out where you left off. '''
    n = 0
    for root, directories, files in os.walk(json_dir):
            item = None
            for filename in files:
                m = n
                item = m, os.path.join(root, filename)
                n += 1
                yield (item)
        
def get_profiles(affiliation_data, url_data, json_files, stop = None):
    ''' Iterate over JSON files and process them '''
    for n, filepath in json_files:
        # keep track of progress
        sys.stdout.flush()
        sys.stdout.write('\r{}'.format(filepath))
        # terminate if stop is specified and reached
        if stop is not None and n >= stop:
            return
        # process this JSON file and harvest the data
        if filepath.endswith(".json"):
            with open(filepath) as f:
                profile = json.load(f)
                for row in get_affiliations(profile):
                    affiliation_data.append(row)
                for row in get_urls(profile):
                    url_data.append(row)

def has_education(profile):
    ''' This tests whether the profile has any educatino affiliations '''
    try:
        if profile["activities-summary"]["educations"]["education-summary"] != None:
            return True
    except:
        return False

def has_employment(profile):
    ''' This tests whether the profile has any employment affiliations '''
    try:
        if profile["activities-summary"]["employments"]["employment-summary"] != None:
            return True
    except:
        return False
    
def has_url(profile):
    ''' This tests whether the profile has any urls '''
    try:
        if profile["person"]["researcher-urls"]["researcher-url"] != None:
            return True
    except:
        return False

def get_affiliations(profile):
    ''' For each profile, extract all affiliations and metadata '''
    profile_data = []
    orcid_id = None
    if has_education(profile):
        orcid_id = profile["orcid-identifier"]["path"]
        for edu in profile["activities-summary"]["educations"]["education-summary"]:
            row = [orcid_id]
            row.append(edu["organization"]["address"]["country"])
            try:
                row.append(edu["organization"]["name"])
            except:
                row.append(None)
            try:
                row.append(edu["organization"]["disambiguated-organization"]["disambiguated-organization-identifier"])
            except:
                row.append(None)
            try:
                row.append(edu["start-date"]["year"]["value"])
            except:
                row.append(None)
            try:
                row.append(edu["end-date"]["year"]["value"])
            except:
                row.append(None)
            try:
                row.append(edu["role-title"])
            except:
                row.append(None)
            row.append(edu["path"][21:30]) #Add education keyword
            try:
                row.append(edu["soure"]["source-name"])
            except:
                row.append(None)
            profile_data.append(row)
    if has_education(profile):
        if orcid_id is None:
            orcid_id = profile["orcid-identifier"]["path"]
        for empl in profile["activities-summary"]["employments"]["employment-summary"]:
            row = [orcid_id]
            row.append(empl["organization"]["address"]["country"])
            try:
                row.append(empl["organization"]["name"])
            except:
                row.append(None)
            try:
                row.append(empl["organization"]["disambiguated-organization"]["disambiguated-organization-identifier"])
            except:
                row.append(None)
            try:
                row.append(empl["start-date"]["year"]["value"])
            except:
                row.append(None)
            try:
                row.append(empl["end-date"]["year"]["value"])
            except:
                row.append(None)
            try:
                row.append(empl["role-title"])
            except:
                row.append(None)
            row.append(empl["path"][21:31]) #Add employement keyword
            try:
                row.append(empl["source"]["source-name"]["value"])
            except:
                row.append(None)
            profile_data.append(row)
    return profile_data

def get_urls(profile):
    ''' For each profile, extract all affiliations and metadata '''
    profile_data = []
    orcid_id = None
    if has_url(profile):
        orcid_id = profile["orcid-identifier"]["path"]
        for url in profile["person"]["researcher-urls"]["researcher-url"]:
            row = [orcid_id]
            row.append(url["url-name"])
            try:
                row.append(url["url"]["value"])
            except:
                row.append(None)
            try:
                row.append(url["source"]["source-name"]["value"])
            except:
                row.append(None)
            profile_data.append(row)
    return profile_data

# %% [markdown]
# ### Testing

# %%
json_dir = "/media/eva/Eva-passport/ORCIDpubData2017/public_profiles_API-2.0_2017_10_json/0"
json_files = file_generator(json_dir)

# %%
affiliation_data = []
url_data = []

# %%
# %%time
get_profiles(affiliation_data, url_data, json_files, stop=25)
# Out:
# /media/eva/Eva-passport/ORCIDpubData2017/public_profiles_API-2.0_2017_10_json/0/0000-0002-1319-0750.jsonCPU times: user 907 ms, sys: 202 ms, total: 1.11 s
# Wall time: 1.66 s

# %%
aff = pd.DataFrame(affiliation_data, columns = ["orcid_id", "country", "organization_name", 
                              "organization_id", "start_year", "end_year", "affiliation_role" ,"affiliation_type","source"])

url = pd.DataFrame(url_data, columns =["orcid_id", "url_name", "url", "source"])

# %%
print ("affiliations:", len(aff), "; unique profiles:", aff.orcid_id.nunique())
print ("urls:", len(url), "; unique profiles:", url.orcid_id.nunique())
# Out:
# affiliations: 5 ; unique profiles: 2
# urls: 8 ; unique profiles: 3

# %%
aff.head()
# Out:
#               orcid_id country  \
# 0  0000-0001-5000-1640      KR
# 1  0000-0001-5000-1640      KR
# 2  0000-0001-5000-4390      IN
# 3  0000-0001-5000-4390      IN
# 4  0000-0001-5000-4390      GB
#
#                                    organization_name organization_id  \
# 0  Sogang University Graduate School of Internati...           92200
# 1   Citizens' Alliance for North Korean Human Rights            None
# 2                                University of Delhi           28742
# 3                                University of Delhi           28742
# 4                              King's College London            None
#
#   start_year end_year         affiliation_role affiliation_type  \
# 0       2005     2016                     Ph.D        education
# 1       2004     None  Deputy Director General       employment
# 2       None     1986                      PhD        education
# 3       None     1981                     None        education
# 4       None     None                   Reader       employment
#
#             source
# 0             None
# 1  Joanna Hosaniak
# 2             None
# 3             None
# 4     Sanjukta Deb

# %%
url.head()
# Out:
#               orcid_id                url_name  \
# 0  0000-0001-5000-2520        UCL IRIS Profile
# 1  0000-0001-5001-2390  hoc tieng anh moi ngay
# 2  0000-0001-5001-4070             Web Address
# 3  0000-0001-5001-4070                 Google+
# 4  0000-0001-5001-4070                Facebook
#
#                                                  url                  source
# 0  http://iris.ucl.ac.uk/iris/browse/profile?upi=...  UCL ORCID Registration
# 1  http://www.hoctienganhmoingay.biz/2015/05/hoc-...              Ngo Nguyet
# 2            http://www.cosmeticdentistrycenter.com/        Dmitriy Epelboym
# 3   https://plus.google.com/+Cosmeticdentistrycenter        Dmitriy Epelboym
# 4  https://www.facebook.com/nycosmeticdentistryce...        Dmitriy Epelboym

# %% [markdown]
# ### Reading in all data
# After successful testing of the setup, the code can now be run with all data files

# %%
json_dir = "/media/eva/Eva-passport/ORCIDpubData2017/public_profiles_API-2.0_2017_10_json"
json_files = file_generator(json_dir)

# %%
#data = [] #commenting this out, so we don't accidentally reset the data frame!

# %%
# %%time
get_profiles(data, json_files)

# %%
df = pd.DataFrame(data, columns = ["orcid_id", "country", "organization_name", 
                              "Ringgold_id", "start_year", "end_year", "affiliation_role"])
df.head()

# %%
len(df), df.orcid_id.nunique()

# %%
affiliation_without_dates = df[((df["start_year"].isnull()) & (df["end_year"].isnull()))]
len(affiliation_without_dates), affiliation_without_dates.orcid_id.nunique()

# %%
UStA_all = df[(df.organization_name == "University of St Andrews")]
len(UStA_all), UStA_all.orcid_id.nunique()

# %%
df.dtypes

# %%
df[df.orcid_id =="0000-0003-4965-2969"]
